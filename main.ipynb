# %%
def func(sum,i,n):
    if i> n:
        print("Sum =",sum)
        return
    func(sum+i,i+1,n)

func(0,1,4)
# Out:
# Sum = 10

# %%
def func(i,n): 
    global sum
    if i>n:
        print(sum)
        return
    sum = sum + i
    func(i+1,n)
func(1,4)
# Out:
# 10
